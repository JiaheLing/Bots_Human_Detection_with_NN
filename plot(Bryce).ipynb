# %%
import pandas as pd

''' <Classifier>
BNB: Bernoulli Naive Bayes
MNB: Multinomial Naive Bayes
KNN: K-Nearest Neighbours
NC: NearestCentroid
RC: Ridge Regression
P: Perceptron
PAC: PassiveAggressiveClassifier
LR: Logistic Regression
SVM: linear SVM using liblinear algorithm
SVM(SGD): linear SVM using SGD algorithm
'''
''' <Featurization>
BOWx: Bag of Word w/o data preprocessing
BOW: Bag of Word w/ data preprocessing
TF-IDF w/ data preprocessing
'''
BOWx = [0.707125, 0.7060416666666667, 0.7702083333333334, 0.5980416666666667, 0.763125, 0.7381666666666666, 0.7334583333333333, 0.76975, 0.7495, 0.7855]
BOW = [0.7119583333333334, 0.708, 0.7727916666666667, 0.59925, 0.766125, 0.7193333333333334, 0.7314583333333333, 0.775875, 0.7527083333333333, 0.7896666666666666]
TF_IDF = [0.7119583333333334, 0.7675833333333333, 0.768625, 0.6395416666666667, 0.7886666666666666, 0.7155416666666666, 0.743875, 0.7865833333333333, 0.7839166666666667, 0.7804583333333334]
index = ['BNB', 'MNB', 'KNN', 'NC', 'RC', 'P', 'PAC', 'LR', 'SVM', 'SVM(SGD)']
df = pd.DataFrame({'BOWx': BOWx, 'BOW': BOW, 'TF-IDF': TF_IDF}, index=index)
ax = df.plot.bar(rot=0, figsize=(16, 8))
ax.set_ylim(bottom=0.59, top=0.8)
ax
